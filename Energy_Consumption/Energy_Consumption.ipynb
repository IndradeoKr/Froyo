# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %%
df = pd.read_csv("AEP_hourly.csv")
print("="*50)
print("First Five Rows ","\n")
print(df.head(5),"\n")
print(df.tail(5),"\n")
print("="*50)
print("Information About Dataset","\n")
print(df.info(),"\n")

print("="*50)
print("Describe the Dataset ","\n")
print(df.describe(),"\n")

print("="*50)
print("Null Values t ","\n")
print(df.isnull().sum(),"\n")
# Out:
# ==================================================
# First Five Rows
#
#               Datetime   AEP_MW
# 0  2004-12-31 01:00:00  13478.0
# 1  2004-12-31 02:00:00  12865.0
# 2  2004-12-31 03:00:00  12577.0
# 3  2004-12-31 04:00:00  12517.0
# 4  2004-12-31 05:00:00  12670.0
#
#                    Datetime   AEP_MW
# 121268  2018-01-01 20:00:00  21089.0
# 121269  2018-01-01 21:00:00  20999.0
# 121270  2018-01-01 22:00:00  20820.0
# 121271  2018-01-01 23:00:00  20415.0
# 121272  2018-01-02 00:00:00  19993.0
#
# ==================================================
# Information About Dataset
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121273 entries, 0 to 121272
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  121273 non-null  object
#  1   AEP_MW    121273 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ MB
# None
#
# ==================================================
# Describe the Dataset
#
#               AEP_MW
# count  121273.000000
# mean    15499.513717
# std      2591.399065
# min      9581.000000
# 25%     13630.000000
# 50%     15310.000000
# 75%     17200.000000
# max     25695.000000
#
# ==================================================
# Null Values t
#
# Datetime    0
# AEP_MW      0
# dtype: int64

# %%
# Extract all Data Like Year MOnth Day Time etc
dataset = df
dataset["Month"] = pd.to_datetime(df["Datetime"]).dt.month
dataset["Year"] = pd.to_datetime(df["Datetime"]).dt.year
dataset["Date"] = pd.to_datetime(df["Datetime"]).dt.date
dataset["Time"] = pd.to_datetime(df["Datetime"]).dt.time
dataset["Week"] = pd.to_datetime(df["Datetime"]).dt.week
dataset["Day"] = pd.to_datetime(df["Datetime"]).dt.day_name()
dataset = df.set_index("Datetime")
dataset.index = pd.to_datetime(dataset.index)
dataset.head(1)
# Out:
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\4122373622.py:7: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   dataset["Week"] = pd.to_datetime(df["Datetime"]).dt.week
#                       AEP_MW  Month  Year        Date      Time  Week     Day
# Datetime
# 2004-12-31 01:00:00  13478.0     12  2004  2004-12-31  01:00:00    53  Friday

# %%
# How many Unique Year do we Have in Dataset 
print(df.Year.unique(),"\n")
print("Total Number of Unique Year", df.Year.nunique(), "\n")
# Out:
# [2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018]
#
# Total Number of Unique Year 15

# %%
from matplotlib import style

fig = plt.figure()
# ax1 = plt.subplot2grid((1,1), (0,0))

style.use('ggplot')

sns.lineplot(x=dataset["Year"], y=dataset["AEP_MW"], data=df)
sns.set(rc={'figure.figsize':(15,6)})

plt.title("Energy consumptionnin Year 2004")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()

plt.title("Energy Consumption According to Year")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 1.0, 'Energy Consumption According to Year')

# %%
from matplotlib import style
fig = plt.figure()
style.use('ggplot')

y_2004 = dataset["2004"]["AEP_MW"].to_list()
x_2004 = dataset["2004"]["Date"].to_list()
sns.lineplot(x=x_2004, y=y_2004, data=dataset["2004"])
sns.set(rc={'figure.figsize':(15,6)})

plt.title("Energy consumptionnin in year 2004")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()
# Out:
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\4154987183.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   y_2004 = dataset["2004"]["AEP_MW"].to_list()
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\4154987183.py:6: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   x_2004 = dataset["2004"]["Date"].to_list()
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\4154987183.py:7: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   sns.lineplot(x=x_2004, y=y_2004, data=dataset["2004"])
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y_2005 = dataset["2005"]["AEP_MW"].to_list()
x_2005 = dataset["2005"]["Date"].to_list()
sns.lineplot(x=x_2005, y=y_2005, data=dataset["2005"])
sns.set(rc={'figure.figsize':(15,6)})

plt.title("Energy consumptionnin in year 2005")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()
# Out:
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\606790833.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   y_2005 = dataset["2005"]["AEP_MW"].to_list()
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\606790833.py:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   x_2005 = dataset["2005"]["Date"].to_list()
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\606790833.py:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   sns.lineplot(x=x_2005, y=y_2005, data=dataset["2005"])
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y_2006 = dataset["2006"]["AEP_MW"].to_list()
x_2006 = dataset["2006"]["Date"].to_list()
sns.lineplot(x=x_2006, y=y_2006, data=dataset["2006"])
sns.set(rc={'figure.figsize':(15,6)})

plt.title("Energy consumptionnin in year 2006")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()
# Out:
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\1384600394.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   y_2006 = dataset["2006"]["AEP_MW"].to_list()
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\1384600394.py:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   x_2006 = dataset["2006"]["Date"].to_list()
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\1384600394.py:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   sns.lineplot(x=x_2006, y=y_2006, data=dataset["2006"])
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.histplot(dataset["AEP_MW"])
plt.title("Energy Distribution")
# Out:
# Text(0.5, 1.0, 'Energy Distribution')

# %%
fig = plt.figure()
ax1= fig.add_subplot(111)

sns.lineplot(x=dataset["Time"].astype(str),y=dataset["AEP_MW"], data=df)
plt.title("Energy Consumption vs Time ")
plt.xlabel("Time")
plt.grid(True, alpha=1)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
NewDataSet = dataset.resample('D').mean()
NewDataSet
# Out:
# C:\Users\indra\AppData\Local\Temp\ipykernel_8716\3017776633.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   NewDataSet = dataset.resample('D').mean()
#                   AEP_MW  Month    Year  Week
# Datetime
# 2004-10-01  14284.521739   10.0  2004.0  40.0
# 2004-10-02  12999.875000   10.0  2004.0  40.0
# 2004-10-03  12227.083333   10.0  2004.0  40.0
# 2004-10-04  14309.041667   10.0  2004.0  41.0
# 2004-10-05  14439.708333   10.0  2004.0  41.0
# ...                  ...    ...     ...   ...
# 2018-07-30  15368.083333    7.0  2018.0  31.0
# 2018-07-31  15180.291667    7.0  2018.0  31.0
# 2018-08-01  15151.166667    8.0  2018.0  31.0
# 2018-08-02  15687.666667    8.0  2018.0  31.0
# 2018-08-03  14809.000000    8.0  2018.0  31.0
#
# [5055 rows x 4 columns]

# %%
print("Old Dataset ",dataset.shape )
print("New  Dataset ",NewDataSet.shape )
# Out:
# Old Dataset  (121273, 7)
# New  Dataset  (5055, 4)

# %%
TestData = NewDataSet.tail(100)

Training_Set = NewDataSet.iloc[:,0:1]

Training_Set = Training_Set[:-60]

# %%
print("Training Set Shape ", Training_Set.shape)
print("Test Set Shape ", TestData.shape)
# Out:
# Training Set Shape  (4995, 1)
# Test Set Shape  (100, 4)

# %%
Training_Set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4995 entries, 2004-10-01 to 2018-06-04
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AEP_MW  4995 non-null   float64
# dtypes: float64(1)
# memory usage: 78.0 KB

# %%
TestData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100 entries, 2018-04-26 to 2018-08-03
# Freq: D
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AEP_MW  100 non-null    float64
#  1   Month   100 non-null    float64
#  2   Year    100 non-null    float64
#  3   Week    100 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %%
Training_Set = Training_Set
sc = MinMaxScaler(feature_range=(0, 1))
Train = sc.fit_transform(Training_Set)

# %%
X_Train = []
Y_Train = []

# Range should be from 60 Values to END 
for i in range(60, Train.shape[0]):
    
    # X_Train 0-59 
    X_Train.append(Train[i-60:i])
    
    # Y Would be 60 th Value based on past 60 Values 
    Y_Train.append(Train[i])

# Convert into Numpy Array
X_Train = np.array(X_Train)
Y_Train = np.array(Y_Train)

print(X_Train.shape)
print(Y_Train.shape)
# Out:
# (4935, 60, 1)
# (4935, 1)

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dense, Dropout
from keras.optimizers import Adam

# %%
regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_Train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
optimizer = Adam(learning_rate=0.001)  # Adjust the learning rate
regressor.compile(optimizer=optimizer, loss='mean_squared_error')
# regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# C:\Users\indra\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
regressor.fit(X_Train, Y_Train, epochs = 25, batch_size = 32)
# Out:
# Epoch 1/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 16s 100ms/step - loss: 0.0299
# Epoch 2/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - loss: 0.0187
# Epoch 3/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 94ms/step - loss: 0.0172
# Epoch 4/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 95ms/step - loss: 0.0167
# Epoch 5/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - loss: 0.0164
# Epoch 6/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - loss: 0.0153
# Epoch 7/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 96ms/step - loss: 0.0152
# Epoch 8/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - loss: 0.0142
# Epoch 9/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - loss: 0.0125
# Epoch 10/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 16s 103ms/step - loss: 0.0106
# Epoch 11/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - loss: 0.0092
# Epoch 12/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 0.0092
# Epoch 13/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 96ms/step - loss: 0.0088
# Epoch 14/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 109ms/step - loss: 0.0077
# Epoch 15/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 0.0081
# Epoch 16/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - loss: 0.0076
# Epoch 17/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 16s 100ms/step - loss: 0.0075
# Epoch 18/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - loss: 0.0072
# Epoch 19/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 94ms/step - loss: 0.0072
# Epoch 20/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 0.0066
# Epoch 21/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 0.0063
# Epoch 22/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - loss: 0.0062
# Epoch 23/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - loss: 0.0055
# Epoch 24/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 16s 105ms/step - loss: 0.0054
# Epoch 25/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - loss: 0.0053

# %%
Df_Total = pd.concat((NewDataSet[["AEP_MW"]], TestData[["AEP_MW"]]), axis=0)

# %%
inputs = Df_Total[len(Df_Total) - len(TestData) - 60:].values

# %%
# We need to Reshape
inputs = inputs.reshape(-1,1)

# Normalize the Dataset
inputs = sc.transform(inputs)

X_test = []
for i in range(60, 160):
    X_test.append(inputs[i-60:i])

Y_test = []
for i in range(60, 160):
    Y_test.append(inputs[i])
# Convert into Numpy Array
X_test = np.array(X_test)
Y_test = np.array(Y_test)
# Reshape before Passing to Network
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
# Pass to Model 
Y_pred = regressor.predict(X_test)

# Do inverse Transformation to get Values 
Y_pred = sc.inverse_transform(Y_pred)
# Out:
# C:\Users\indra\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 316ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

Y_test = sc.inverse_transform(Y_test)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(Y_test, Y_pred)
print(f'Mean Absolute Error (MAE): {mae:.2f}')

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mean_squared_error(Y_test, Y_pred))
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

# R-squared (Coefficient of Determination)
r2 = r2_score(Y_test, Y_pred)
print(f'R-squared (R2 Score): {r2:.2f}')
# Out:
# Mean Absolute Error (MAE): 640.85
# Root Mean Squared Error (RMSE): 798.29
# R-squared (R2 Score): 0.72

# %%
True_MegaWatt = TestData["AEP_MW"].to_list()
Predicted_MegaWatt  = Y_pred
dates = TestData.index.to_list()

# %%
Machine_Df = pd.DataFrame(data={
    "Date":dates,
    "TrueMegaWatt": True_MegaWatt,
    "PredictedMeagWatt":[x[0] for x in Predicted_MegaWatt ]
})

# %%
Machine_Df
# Out:
#          Date  TrueMegaWatt  PredictedMeagWatt
# 0  2018-04-26  13157.791667       13870.533203
# 1  2018-04-27  12964.000000       13840.781250
# 2  2018-04-28  12237.583333       14600.498047
# 3  2018-04-29  12156.791667       13463.981445
# 4  2018-04-30  13443.500000       13029.877930
# ..        ...           ...                ...
# 95 2018-07-30  15368.083333       15216.532227
# 96 2018-07-31  15180.291667       15848.719727
# 97 2018-08-01  15151.166667       15356.916016
# 98 2018-08-02  15687.666667       15342.223633
# 99 2018-08-03  14809.000000       15314.722656
#
# [100 rows x 3 columns]

# %%
fig = plt.figure()

ax1= fig.add_subplot(111)

x = dates
y = True_MegaWatt

y1 = Predicted_MegaWatt

plt.plot(x,y, color="green")
plt.plot(x,y1, color="red")
# beautify the x-labels
plt.gcf().autofmt_xdate()
plt.xlabel('Dates')
plt.ylabel("Power in MW")
plt.title("Machine Learned the Pattern Predicting Future Values ")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
